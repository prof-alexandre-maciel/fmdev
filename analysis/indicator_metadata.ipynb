# %%
import json
import math
import pandas as pd
import pandas as pd
from scipy.stats import pearsonr

# %%
df = pd.read_csv("data/request.csv")

# %% [markdown]
# ## Correlação

# %%
# Only compute pearson prod-moment correlations between feature
# columns and target column
target_col_name = 'desempenho'
correlation_items = {}
for col in df:
    try:
        if target_col_name != col:
            correlation_items[col] = \
            pearsonr(df[col], df[target_col_name])[0]
    except:
        pass

# %%
correlation_items
# Out:
# {'curso': nan,
#  'data_de_final': nan,
#  'data_de_início': nan,
#  'nome_da_disciplina': nan,
#  'período': nan,
#  'desempenho_binario': -0.9201375983879033,
#  'forum01': 0.581964840307422,
#  'forum02': 0.8422361732324133,
#  'forum03': 0.7499751761186862,
#  'forum04': 0.775897406300032,
#  'id_da_disciplina': nan,
#  'id_do_aluno': 0.10233953433461718,
#  'media_forum': 0.8816215646940033,
#  'media_provas': 0.9433296723053927,
#  'media_webquest': 0.9075451748741082,
#  'primeira_prova': 0.8878736690203827,
#  'prova01': 0.8976102019513283,
#  'prova01_2chamada': 0.09997195634356171,
#  'prova02': 0.886257580261476,
#  'prova02_2chamada': 0.020585352983920606,
#  'segunda_prova': 0.8847571947519896,
#  'semestre': nan,
#  'var01': 0.16923413390842365,
#  'var02': 0.028088390894951725,
#  'var03': 0.0745161366254585,
#  'var04': 0.24161653798540478,
#  'var05': 0.2632071809960847,
#  'var06': 0.28987461376866985,
#  'var07': 0.28987461376866985,
#  'var08': 0.18367459206795322,
#  'var09': 0.7996408814047794,
#  'var10': 0.24685109580000036,
#  'var12': nan,
#  'var13': 0.7538783814785918,
#  'var14': 0.6930780707867527,
#  'var15': 0.9058080499261322,
#  'var16': nan,
#  'var17': 0.6178019947664435,
#  'var18': 0.5860289193816187,
#  'var19': 0.7535443386822278,
#  'var20': 0.24300419803463214,
#  'var21': nan,
#  'var22': nan,
#  'var23': nan,
#  'var24': 0.6163539765346905,
#  'var25': 0.7187427346786185,
#  'var28': 0.37699816275650994,
#  'var29': 0.6178019947664435,
#  'var30': 0.6178019947664435,
#  'var31': 0.6213179919694402,
#  'var31b': nan,
#  'var31c': 0.6268751408946772,
#  'var32a': 0.5394079737257094,
#  'var32b': 0.5412412484108076,
#  'var32c': 0.40048315423778824,
#  'var32d': 0.030928006087187602,
#  'var33': 0.9058080499261322,
#  'var34': 0.7535443386822278,
#  'var35': nan,
#  'webquest01': 0.8527061642797277,
#  'webquest02': 0.8798108983276953}

# %% [markdown]
# ## Análise descritiva dos dados

# %%
overview_items = json.loads(df.describe().to_json(force_ascii=False))

# %% [markdown]
# ## Tipos

# %%
type_items = df.dtypes.apply(lambda x: x.name).to_dict()

# %% [markdown]
# ## Unique

# %%
unique_items = {}

for column in df.columns:
    unique_items[column] = df[column].nunique()

# %% [markdown]
# ## Count Null

# %%
null_items = df.isna().sum().apply(lambda x: x).to_dict()

# %%
data = []

for column in df.columns:
    corr = None
    descriptive = {
        "count": None,
        "mean": None,
        "std": None,
        "min": None,
        "25%": None,
        "50%": None,
        "75%": None,
        "max": None
    }
    
    if column in overview_items:
        descriptive = overview_items[column]
    
    if column in correlation_items:
        if math.isnan(correlation_items[column]) == False:
            corr = "%.2f" % correlation_items[column]
            corr = float(corr)
    
    item = {
        'indicator': column,
        'type': type_items[column],
        'missing': null_items[column],
        'unique': unique_items[column],
        'mean': descriptive['mean'],
        "std": descriptive['std'],
        "min": descriptive['min'],
        "25%": descriptive['25%'],
        "50%": descriptive['50%'],
        "75%": descriptive['75%'],
        "max": descriptive['max'],
        "corr": corr
    }
    
    data.append(item)

data
# Out:
# [{'indicator': 'curso',
#   'type': 'object',
#   'missing': 0,
#   'unique': 1,
#   'mean': None,
#   'std': None,
#   'min': None,
#   '25%': None,
#   '50%': None,
#   '75%': None,
#   'max': None,
#   'corr': None},
#  {'indicator': 'data_de_final',
#   'type': 'int64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 1293667200.0,
#   'std': 0.0,
#   'min': 1293667200.0,
#   '25%': 1293667200.0,
#   '50%': 1293667200.0,
#   '75%': 1293667200.0,
#   'max': 1293667200.0,
#   'corr': None},
#  {'indicator': 'data_de_início',
#   'type': 'int64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 1277942400.0,
#   'std': 0.0,
#   'min': 1277942400.0,
#   '25%': 1277942400.0,
#   '50%': 1277942400.0,
#   '75%': 1277942400.0,
#   'max': 1277942400.0,
#   'corr': None},
#  {'indicator': 'nome_da_disciplina',
#   'type': 'object',
#   'missing': 0,
#   'unique': 1,
#   'mean': None,
#   'std': None,
#   'min': None,
#   '25%': None,
#   '50%': None,
#   '75%': None,
#   'max': None,
#   'corr': None},
#  {'indicator': 'nome_do_aluno',
#   'type': 'object',
#   'missing': 0,
#   'unique': 77,
#   'mean': None,
#   'std': None,
#   'min': None,
#   '25%': None,
#   '50%': None,
#   '75%': None,
#   'max': None,
#   'corr': None},
#  {'indicator': 'período',
#   'type': 'int64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 2.0,
#   'std': 0.0,
#   'min': 2.0,
#   '25%': 2.0,
#   '50%': 2.0,
#   '75%': 2.0,
#   'max': 2.0,
#   'corr': None},
#  {'indicator': 'desempenho_classes',
#   'type': 'object',
#   'missing': 0,
#   'unique': 3,
#   'mean': None,
#   'std': None,
#   'min': None,
#   '25%': None,
#   '50%': None,
#   '75%': None,
#   'max': None,
#   'corr': None},
#  {'indicator': 'desempenho',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 57,
#   'mean': 4.7042207792,
#   'std': 2.7573031095,
#   'min': 0.0,
#   '25%': 2.3,
#   '50%': 5.95,
#   '75%': 6.725,
#   'max': 8.6,
#   'corr': None},
#  {'indicator': 'desempenho_binario',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 2,
#   'mean': 0.3376623377,
#   'std': 0.4760138656,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 1.0,
#   'max': 1.0,
#   'corr': -0.92},
#  {'indicator': 'forum01',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 5,
#   'mean': 5.7532467532,
#   'std': 3.0485365089,
#   'min': 0.0,
#   '25%': 6.0,
#   '50%': 7.0,
#   '75%': 7.0,
#   'max': 9.0,
#   'corr': 0.58},
#  {'indicator': 'forum02',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 6,
#   'mean': 4.1428571429,
#   'std': 3.4171174591,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 6.0,
#   '75%': 7.0,
#   'max': 10.0,
#   'corr': 0.84},
#  {'indicator': 'forum03',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 7,
#   'mean': 4.4155844156,
#   'std': 3.310074929,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 6.0,
#   '75%': 7.0,
#   'max': 10.0,
#   'corr': 0.75},
#  {'indicator': 'forum04',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 7,
#   'mean': 4.7532467532,
#   'std': 3.5249331616,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 6.0,
#   '75%': 7.0,
#   'max': 10.0,
#   'corr': 0.78},
#  {'indicator': 'id_da_disciplina',
#   'type': 'int64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 27.0,
#   'std': 0.0,
#   'min': 27.0,
#   '25%': 27.0,
#   '50%': 27.0,
#   '75%': 27.0,
#   'max': 27.0,
#   'corr': None},
#  {'indicator': 'id_do_aluno',
#   'type': 'int64',
#   'missing': 0,
#   'unique': 77,
#   'mean': 806.5974025974,
#   'std': 28.1608442888,
#   'min': 758.0,
#   '25%': 782.0,
#   '50%': 808.0,
#   '75%': 831.0,
#   'max': 852.0,
#   'corr': 0.1},
#  {'indicator': 'media_forum',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 24,
#   'mean': 0.9532467532,
#   'std': 0.5597425197,
#   'min': 0.0,
#   '25%': 0.4,
#   '50%': 1.2,
#   '75%': 1.35,
#   'max': 1.95,
#   'corr': 0.88},
#  {'indicator': 'media_provas',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 16,
#   'mean': 2.5642857143,
#   'std': 1.5071890694,
#   'min': 0.0,
#   '25%': 1.65,
#   '50%': 3.025,
#   '75%': 3.575,
#   'max': 4.95,
#   'corr': 0.94},
#  {'indicator': 'media_webquest',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 12,
#   'mean': 1.1866883117,
#   'std': 0.9278280419,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.5,
#   '75%': 1.875,
#   'max': 2.375,
#   'corr': 0.91},
#  {'indicator': 'primeira_prova',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 9,
#   'mean': 4.2337662338,
#   'std': 2.7381135645,
#   'min': 0.0,
#   '25%': 3.0,
#   '50%': 5.0,
#   '75%': 6.0,
#   'max': 10.0,
#   'corr': 0.89},
#  {'indicator': 'prova01',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 9,
#   'mean': 4.0519480519,
#   'std': 2.8557241864,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 5.0,
#   '75%': 6.0,
#   'max': 10.0,
#   'corr': 0.9},
#  {'indicator': 'prova01_2chamada',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 7,
#   'mean': 0.8311688312,
#   'std': 1.9561145524,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 8.0,
#   'corr': 0.1},
#  {'indicator': 'prova02',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 10,
#   'mean': 5.038961039,
#   'std': 3.1011099814,
#   'min': 0.0,
#   '25%': 3.0,
#   '50%': 6.0,
#   '75%': 8.0,
#   'max': 10.0,
#   'corr': 0.89},
#  {'indicator': 'prova02_2chamada',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 3,
#   'mean': 0.1818181818,
#   'std': 0.9831109688,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 6.0,
#   'corr': 0.02},
#  {'indicator': 'segunda_prova',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 10,
#   'mean': 5.0909090909,
#   'std': 3.0957603359,
#   'min': 0.0,
#   '25%': 3.0,
#   '50%': 6.0,
#   '75%': 8.0,
#   'max': 10.0,
#   'corr': 0.88},
#  {'indicator': 'semestre',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 2010.2,
#   'std': 0.0,
#   'min': 2010.2,
#   '25%': 2010.2,
#   '50%': 2010.2,
#   '75%': 2010.2,
#   'max': 2010.2,
#   'corr': None},
#  {'indicator': 'var01',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 45,
#   'mean': 31.2987012987,
#   'std': 29.7388037026,
#   'min': 3.0,
#   '25%': 10.0,
#   '50%': 22.0,
#   '75%': 43.0,
#   'max': 154.0,
#   'corr': 0.17},
#  {'indicator': 'var02',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 2,
#   'mean': 0.012987013,
#   'std': 0.1139605765,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 1.0,
#   'corr': 0.03},
#  {'indicator': 'var03',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 34,
#   'mean': 17.038961039,
#   'std': 21.2252590081,
#   'min': 0.0,
#   '25%': 4.0,
#   '50%': 11.0,
#   '75%': 22.0,
#   'max': 147.0,
#   'corr': 0.07},
#  {'indicator': 'var04',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 50,
#   'mean': 46.0,
#   'std': 50.3061678755,
#   'min': 0.0,
#   '25%': 15.0,
#   '50%': 32.0,
#   '75%': 63.0,
#   'max': 321.0,
#   'corr': 0.24},
#  {'indicator': 'var05',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 54,
#   'mean': 126.8181818182,
#   'std': 40.86940925,
#   'min': 39.0,
#   '25%': 104.0,
#   '50%': 122.0,
#   '75%': 144.0,
#   'max': 272.0,
#   'corr': 0.26},
#  {'indicator': 'var06',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 3,
#   'mean': 0.1298701299,
#   'std': 0.408806007,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 2.0,
#   'corr': 0.29},
#  {'indicator': 'var07',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 3,
#   'mean': 0.1298701299,
#   'std': 0.408806007,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 2.0,
#   'corr': 0.29},
#  {'indicator': 'var08',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 7,
#   'mean': 0.4935064935,
#   'std': 1.3241022443,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 7.0,
#   'corr': 0.18},
#  {'indicator': 'var09',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 8,
#   'mean': 3.025974026,
#   'std': 1.8985730512,
#   'min': 0.0,
#   '25%': 1.0,
#   '50%': 3.0,
#   '75%': 4.0,
#   'max': 8.0,
#   'corr': 0.8},
#  {'indicator': 'var10',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 16,
#   'mean': 4.5584415584,
#   'std': 4.0343704475,
#   'min': 0.0,
#   '25%': 1.0,
#   '50%': 4.0,
#   '75%': 6.0,
#   'max': 19.0,
#   'corr': 0.25},
#  {'indicator': 'var12',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 0.0,
#   'std': 0.0,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 0.0,
#   'corr': None},
#  {'indicator': 'var13',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 15,
#   'mean': 8.987012987,
#   'std': 7.4753868171,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 10.0,
#   '75%': 16.0,
#   'max': 22.0,
#   'corr': 0.75},
#  {'indicator': 'var14',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 4,
#   'mean': 1.1948051948,
#   'std': 1.0518024759,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.0,
#   '75%': 2.0,
#   'max': 3.0,
#   'corr': 0.69},
#  {'indicator': 'var15',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 3,
#   'mean': 1.2337662338,
#   'std': 0.9444589637,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 2.0,
#   '75%': 2.0,
#   'max': 2.0,
#   'corr': 0.91},
#  {'indicator': 'var16',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 0.0,
#   'std': 0.0,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 0.0,
#   'corr': None},
#  {'indicator': 'var17',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 18,
#   'mean': 7.2987012987,
#   'std': 7.9224280819,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 9.5,
#   '75%': 10.5,
#   'max': 30.0,
#   'corr': 0.62},
#  {'indicator': 'var18',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 45,
#   'mean': 31.4025974026,
#   'std': 27.5901678427,
#   'min': 0.0,
#   '25%': 15.0,
#   '50%': 27.0,
#   '75%': 39.0,
#   'max': 165.0,
#   'corr': 0.59},
#  {'indicator': 'var19',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 10,
#   'mean': 3.5064935065,
#   'std': 2.303449225,
#   'min': 0.0,
#   '25%': 1.0,
#   '50%': 4.0,
#   '75%': 5.0,
#   'max': 9.0,
#   'corr': 0.75},
#  {'indicator': 'var20',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 3,
#   'mean': 0.0519480519,
#   'std': 0.2760674925,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 2.0,
#   'corr': 0.24},
#  {'indicator': 'var21',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 0.0,
#   'std': 0.0,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 0.0,
#   'corr': None},
#  {'indicator': 'var22',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 0.0,
#   'std': 0.0,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 0.0,
#   'corr': None},
#  {'indicator': 'var23',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 0.0,
#   'std': 0.0,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 0.0,
#   'corr': None},
#  {'indicator': 'var24',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 13,
#   'mean': 5.0779220779,
#   'std': 2.8689179776,
#   'min': 0.0,
#   '25%': 3.0,
#   '50%': 5.0,
#   '75%': 7.0,
#   'max': 13.0,
#   'corr': 0.62},
#  {'indicator': 'var25',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 66,
#   'mean': 54.9950649351,
#   'std': 29.1386220289,
#   'min': 0.0,
#   '25%': 37.98,
#   '50%': 67.94,
#   '75%': 73.76,
#   'max': 94.5,
#   'corr': 0.72},
#  {'indicator': 'var28',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 64,
#   'mean': 75.6363636364,
#   'std': 65.4347624277,
#   'min': 0.0,
#   '25%': 27.0,
#   '50%': 53.0,
#   '75%': 105.0,
#   'max': 267.0,
#   'corr': 0.38},
#  {'indicator': 'var29',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 18,
#   'mean': 7.2987012987,
#   'std': 7.9224280819,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 9.5,
#   '75%': 10.5,
#   'max': 30.0,
#   'corr': 0.62},
#  {'indicator': 'var30',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 18,
#   'mean': 7.2987012987,
#   'std': 7.9224280819,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 9.5,
#   '75%': 10.5,
#   'max': 30.0,
#   'corr': 0.62},
#  {'indicator': 'var31',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 71,
#   'mean': 145.4155844156,
#   'std': 74.2873777352,
#   'min': 20.0,
#   '25%': 93.0,
#   '50%': 142.0,
#   '75%': 193.0,
#   'max': 346.0,
#   'corr': 0.62},
#  {'indicator': 'var31b',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 0.0,
#   'std': 0.0,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 0.0,
#   'corr': None},
#  {'indicator': 'var31c',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 62,
#   'mean': 80.5064935065,
#   'std': 35.1038397122,
#   'min': 14.0,
#   '25%': 53.0,
#   '50%': 81.0,
#   '75%': 102.0,
#   'max': 150.0,
#   'corr': 0.63},
#  {'indicator': 'var32a',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 51,
#   'mean': 41.1948051948,
#   'std': 28.4725347628,
#   'min': 3.0,
#   '25%': 20.0,
#   '50%': 35.0,
#   '75%': 59.0,
#   'max': 126.0,
#   'corr': 0.54},
#  {'indicator': 'var32b',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 52,
#   'mean': 48.0649350649,
#   'std': 27.5992647034,
#   'min': 5.0,
#   '25%': 30.0,
#   '50%': 43.0,
#   '75%': 63.0,
#   'max': 120.0,
#   'corr': 0.54},
#  {'indicator': 'var32c',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 52,
#   'mean': 53.1428571429,
#   'std': 39.0902176098,
#   'min': 0.0,
#   '25%': 25.0,
#   '50%': 46.0,
#   '75%': 82.0,
#   'max': 191.0,
#   'corr': 0.4},
#  {'indicator': 'var32d',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 15,
#   'mean': 3.012987013,
#   'std': 6.626290354,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.0,
#   '75%': 3.0,
#   'max': 48.0,
#   'corr': 0.03},
#  {'indicator': 'var33',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 3,
#   'mean': 1.2337662338,
#   'std': 0.9444589637,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 2.0,
#   '75%': 2.0,
#   'max': 2.0,
#   'corr': 0.91},
#  {'indicator': 'var34',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 10,
#   'mean': 3.5064935065,
#   'std': 2.303449225,
#   'min': 0.0,
#   '25%': 1.0,
#   '50%': 4.0,
#   '75%': 5.0,
#   'max': 9.0,
#   'corr': 0.75},
#  {'indicator': 'var35',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 1,
#   'mean': 0.0,
#   'std': 0.0,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 0.0,
#   'corr': None},
#  {'indicator': 'webquest01',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 6,
#   'mean': 4.5974025974,
#   'std': 3.7810460132,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 6.0,
#   '75%': 8.0,
#   'max': 10.0,
#   'corr': 0.85},
#  {'indicator': 'webquest02',
#   'type': 'float64',
#   'missing': 0,
#   'unique': 5,
#   'mean': 4.8961038961,
#   'std': 3.9920460905,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 7.0,
#   '75%': 8.0,
#   'max': 9.0,
#   'corr': 0.88}]

# %%
len(df.index)
# Out:
# 77
