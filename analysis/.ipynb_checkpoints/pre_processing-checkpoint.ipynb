# %%
import json
import math
import pandas as pd
import plotly.offline as offline
import plotly.express as px
from scipy.stats import pearsonr

# %%
df = pd.read_csv("data/request.csv")

# %% [markdown]
# ## Correlação

# %%
# Only compute pearson prod-moment correlations between feature
# columns and target column
target_col_name = 'desempenho'
correlation_items = {}
for col in df:
    try:
        if target_col_name != col:
            correlation_items[col] = \
            pearsonr(df[col], df[target_col_name])[0]
    except:
        pass

# %%
correlation_items
# Out:
# {'curso': nan,
#  'data_de_final': 0.12417696034464978,
#  'data_de_início': 0.12403743165036897,
#  'desempenho_binario': -0.8847490349149028,
#  'forum01': 0.5304222780933984,
#  'forum02': 0.6016672201021609,
#  'forum03': 0.6034101807560337,
#  'forum04': 0.6150771613229821,
#  'id_da_disciplina': 0.15471321438958802,
#  'id_do_aluno': -0.000968838669736322,
#  'media_forum': 0.8019442745597744,
#  'media_provas': 0.907983251854633,
#  'media_webquest': 0.8398966874763164,
#  'período': 0.14258311368571044,
#  'primeira_prova': 0.751755988959008,
#  'prova01': 0.6986730510337389,
#  'prova01_2chamada': 0.08811592637069353,
#  'prova02': 0.6516536680348715,
#  'prova02_2chamada': 0.11702809062118734,
#  'segunda_prova': 0.6858266190960319,
#  'semestre': 0.11162639899787571,
#  'var01': 0.311584911064265,
#  'var02': 0.22902326843829865,
#  'var03': 0.1010901975551252,
#  'var04': 0.18316725122992972,
#  'var05': 0.15789244603105687,
#  'var06': 0.17773054180000158,
#  'var07': 0.17534049335827562,
#  'var08': 0.3418864340183274,
#  'var09': 0.44586631928106246,
#  'var10': 0.13382256157813324,
#  'var12': 0.11648071115812465,
#  'var13': 0.5954746289299631,
#  'var14': 0.5655906180135956,
#  'var15': 0.7823640337552162,
#  'var16': 0.05534794415570551,
#  'var17': 0.27126756514972244,
#  'var18': 0.5768479970855966,
#  'var19': 0.614111836077599,
#  'var20': 0.19607814621777675,
#  'var21': 0.3316793621744375,
#  'var22': 0.11537332114098169,
#  'var23': 0.3071592691418536,
#  'var24': 0.5735248942822164,
#  'var25': 0.47293132669877885,
#  'var28': 0.41281562411014044,
#  'var29': 0.27126756514972244,
#  'var30': 0.27126756514972244,
#  'var31': 0.5733632279077555,
#  'var31b': 0.43413607245733515,
#  'var31c': 0.615609876266909,
#  'var32a': 0.4935461159646017,
#  'var32b': 0.49765071287962825,
#  'var32c': 0.5085359380754266,
#  'var32d': 0.1602592122401753,
#  'var33': 0.7823640337552162,
#  'var34': 0.614111836077599,
#  'var35': 0.13837066306574256,
#  'webquest01': 0.6800589572095999,
#  'webquest02': 0.7143208389351139}

# %% [markdown]
# ## Análise descritiva dos dados

# %%
overview_items = json.loads(df.describe().to_json(force_ascii=False))

# %% [markdown]
# ## Tipos

# %%
type_items = df.dtypes.apply(lambda x: x.name).to_dict()

# %% [markdown]
# ## Unique

# %%
unique_items = {}

for column in df.columns:
    unique_items[column] = df[column].nunique()

# %% [markdown]
# ## Count Null

# %%
null_items = df.isna().sum().apply(lambda x: x).to_dict()

# %%
data = []

for column in df.columns:
    corr = None
    type_column = 'Categórico'
    descriptive = {
        "count": None,
        "mean": None,
        "std": None,
        "min": None,
        "25%": None,
        "50%": None,
        "75%": None,
        "max": None
    }
    
    if column in overview_items:
        descriptive = overview_items[column]
        type_column = 'Discreto'
    
    if column in correlation_items:
        if math.isnan(correlation_items[column]) == False:
            corr = "%.2f" % correlation_items[column]
            corr = float(corr)
    
    item = {
        'indicator': column,
        'type': type_column,
        'missing': null_items[column],
        'unique': unique_items[column],
        'mean': descriptive['mean'],
        "std": descriptive['std'],
        "min": descriptive['min'],
        "25%": descriptive['25%'],
        "50%": descriptive['50%'],
        "75%": descriptive['75%'],
        "max": descriptive['max'],
        "corr": corr
    }
    
    data.append(item)

# %%
data
# Out:
# [{'indicator': 'curso',
#   'type': 'Categórico',
#   'missing': 0,
#   'unique': 1,
#   'mean': None,
#   'std': None,
#   'min': None,
#   '25%': None,
#   '50%': None,
#   '75%': None,
#   'max': None,
#   'corr': None},
#  {'indicator': 'data_de_final',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 7,
#   'mean': 1361812869.3824344,
#   'std': 64104140.89989983,
#   'min': 1277856000.0,
#   '25%': 1309392000.0,
#   '50%': 1388361600.0,
#   '75%': 1420070399.0,
#   'max': 1467331199.0,
#   'corr': 0.12},
#  {'indicator': 'data_de_início',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 7,
#   'mean': 1346095180.0829875,
#   'std': 64026776.30076964,
#   'min': 1262304000.0,
#   '25%': 1293840000.0,
#   '50%': 1372636800.0,
#   '75%': 1404172800.0,
#   'max': 1451606400.0,
#   'corr': 0.12},
#  {'indicator': 'desempenho',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 499,
#   'mean': 4.2434634336,
#   'std': 2.9746792903,
#   'min': 0.0,
#   '25%': 1.0,
#   '50%': 4.86,
#   '75%': 6.65,
#   'max': 10.5,
#   'corr': None},
#  {'indicator': 'desempenho_binario',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 2,
#   'mean': 0.4170124481,
#   'std': 0.4931502401,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 1.0,
#   'max': 1.0,
#   'corr': -0.88},
#  {'indicator': 'desempenho_classes',
#   'type': 'Categórico',
#   'missing': 0,
#   'unique': 3,
#   'mean': None,
#   'std': None,
#   'min': None,
#   '25%': None,
#   '50%': None,
#   '75%': None,
#   'max': None,
#   'corr': None},
#  {'indicator': 'forum01',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 11,
#   'mean': 3.5349239281,
#   'std': 3.5231837138,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 3.0,
#   '75%': 6.0,
#   'max': 10.0,
#   'corr': 0.53},
#  {'indicator': 'forum02',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 11,
#   'mean': 3.3267634855,
#   'std': 3.5774867991,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 2.0,
#   '75%': 5.0,
#   'max': 10.0,
#   'corr': 0.6},
#  {'indicator': 'forum03',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 11,
#   'mean': 3.1390041494,
#   'std': 3.5934969673,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 2.0,
#   '75%': 5.0,
#   'max': 10.0,
#   'corr': 0.6},
#  {'indicator': 'forum04',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 11,
#   'mean': 2.974757953,
#   'std': 3.4856605665,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.0,
#   '75%': 5.0,
#   'max': 10.0,
#   'corr': 0.62},
#  {'indicator': 'id_da_disciplina',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 41,
#   'mean': 38.9298063624,
#   'std': 21.4775449306,
#   'min': 5.0,
#   '25%': 28.0,
#   '50%': 33.0,
#   '75%': 42.25,
#   'max': 84.0,
#   'corr': 0.15},
#  {'indicator': 'id_do_aluno',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 320,
#   'mean': 713.2880359613,
#   'std': 317.8323695034,
#   'min': 5.0,
#   '25%': 631.0,
#   '50%': 782.0,
#   '75%': 833.0,
#   'max': 1501.0,
#   'corr': -0.0},
#  {'indicator': 'media_forum',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 40,
#   'mean': 0.8550656985,
#   'std': 0.7358801824,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.8,
#   '75%': 1.5,
#   'max': 2.0,
#   'corr': 0.8},
#  {'indicator': 'media_provas',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 232,
#   'mean': 2.0367812068,
#   'std': 1.6320524043,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 2.2,
#   '75%': 3.3,
#   'max': 5.5,
#   'corr': 0.91},
#  {'indicator': 'media_webquest',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 23,
#   'mean': 1.3516165284,
#   'std': 1.074737114,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.5,
#   '75%': 2.25,
#   'max': 3.0,
#   'corr': 0.84},
#  {'indicator': 'nome_da_disciplina',
#   'type': 'Categórico',
#   'missing': 0,
#   'unique': 46,
#   'mean': None,
#   'std': None,
#   'min': None,
#   '25%': None,
#   '50%': None,
#   '75%': None,
#   'max': None,
#   'corr': None},
#  {'indicator': 'nome_do_aluno',
#   'type': 'Categórico',
#   'missing': 0,
#   'unique': 450,
#   'mean': None,
#   'std': None,
#   'min': None,
#   '25%': None,
#   '50%': None,
#   '75%': None,
#   'max': None,
#   'corr': None},
#  {'indicator': 'período',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 6,
#   'mean': 3.2520746888,
#   'std': 2.0518392043,
#   'min': 1.0,
#   '25%': 2.0,
#   '50%': 3.0,
#   '75%': 4.0,
#   'max': 8.0,
#   'corr': 0.14},
#  {'indicator': 'primeira_prova',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 132,
#   'mean': 2.8745193638,
#   'std': 2.5234323662,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 3.0,
#   '75%': 4.75,
#   'max': 10.0,
#   'corr': 0.75},
#  {'indicator': 'prova01',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 129,
#   'mean': 2.6160338866,
#   'std': 2.5705624859,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 2.58,
#   '75%': 4.4,
#   'max': 10.0,
#   'corr': 0.7},
#  {'indicator': 'prova01_2chamada',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 64,
#   'mean': 0.506753112,
#   'std': 1.4155253955,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 10.0,
#   'corr': 0.09},
#  {'indicator': 'prova02',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 26,
#   'mean': 2.553973029,
#   'std': 2.8381561659,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 2.0,
#   '75%': 4.95,
#   'max': 10.0,
#   'corr': 0.65},
#  {'indicator': 'prova02_2chamada',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 21,
#   'mean': 0.3190525588,
#   'std': 1.2374789991,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 10.0,
#   'corr': 0.12},
#  {'indicator': 'segunda_prova',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 26,
#   'mean': 2.7495124481,
#   'std': 2.8396532503,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 2.2,
#   '75%': 4.95,
#   'max': 10.0,
#   'corr': 0.69},
#  {'indicator': 'semestre',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 7,
#   'mean': 2012.5054979253,
#   'std': 2.0135602718,
#   'min': 2010.1,
#   '25%': 2011.1,
#   '50%': 2013.2,
#   '75%': 2014.2,
#   'max': 2016.1,
#   'corr': 0.11},
#  {'indicator': 'var01',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 87,
#   'mean': 22.3150069156,
#   'std': 27.8697247845,
#   'min': 0.0,
#   '25%': 5.0,
#   '50%': 12.0,
#   '75%': 30.25,
#   'max': 268.0,
#   'corr': 0.31},
#  {'indicator': 'var02',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 13,
#   'mean': 0.3430152144,
#   'std': 1.1747559352,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 19.0,
#   'corr': 0.23},
#  {'indicator': 'var03',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 69,
#   'mean': 6.2890733057,
#   'std': 13.2697883498,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.0,
#   '75%': 7.0,
#   'max': 147.0,
#   'corr': 0.1},
#  {'indicator': 'var04',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 113,
#   'mean': 26.1739280775,
#   'std': 49.5484470393,
#   'min': 0.0,
#   '25%': 2.0,
#   '50%': 11.0,
#   '75%': 31.0,
#   'max': 572.0,
#   'corr': 0.18},
#  {'indicator': 'var05',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 170,
#   'mean': 59.9737206086,
#   'std': 53.611087831,
#   'min': 0.0,
#   '25%': 21.0,
#   '50%': 49.0,
#   '75%': 89.0,
#   'max': 450.0,
#   'corr': 0.16},
#  {'indicator': 'var06',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 9,
#   'mean': 0.1320885201,
#   'std': 0.5212675745,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 8.0,
#   'corr': 0.18},
#  {'indicator': 'var07',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 14,
#   'mean': 0.2510373444,
#   'std': 0.9649239011,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 14.0,
#   'corr': 0.18},
#  {'indicator': 'var08',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 24,
#   'mean': 0.9107883817,
#   'std': 2.3603861613,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 1.0,
#   'max': 27.0,
#   'corr': 0.34},
#  {'indicator': 'var09',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 22,
#   'mean': 1.6082295989,
#   'std': 2.6284453686,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 2.0,
#   'max': 23.0,
#   'corr': 0.45},
#  {'indicator': 'var10',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 23,
#   'mean': 2.4152835408,
#   'std': 3.5746834789,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.0,
#   '75%': 3.0,
#   'max': 23.0,
#   'corr': 0.13},
#  {'indicator': 'var12',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 18,
#   'mean': 0.2790456432,
#   'std': 1.4917981885,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 43.0,
#   'corr': 0.12},
#  {'indicator': 'var13',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 24,
#   'mean': 9.5629322268,
#   'std': 7.8146893215,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 10.0,
#   '75%': 17.0,
#   'max': 23.0,
#   'corr': 0.6},
#  {'indicator': 'var14',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 5,
#   'mean': 1.352351314,
#   'std': 1.1533948224,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.0,
#   '75%': 2.0,
#   'max': 4.0,
#   'corr': 0.57},
#  {'indicator': 'var15',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 3,
#   'mean': 1.1320885201,
#   'std': 0.9045681724,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.0,
#   '75%': 2.0,
#   'max': 2.0,
#   'corr': 0.78},
#  {'indicator': 'var16',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 3,
#   'mean': 0.0871369295,
#   'std': 0.3389004408,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 2.0,
#   'corr': 0.06},
#  {'indicator': 'var17',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 340,
#   'mean': 5.9927593361,
#   'std': 11.2813576288,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.605,
#   '75%': 7.5,
#   'max': 69.0,
#   'corr': 0.27},
#  {'indicator': 'var18',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 162,
#   'mean': 27.1649377593,
#   'std': 32.5973746786,
#   'min': 0.0,
#   '25%': 2.0,
#   '50%': 18.0,
#   '75%': 39.0,
#   'max': 277.0,
#   'corr': 0.58},
#  {'indicator': 'var19',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 38,
#   'mean': 4.0224757953,
#   'std': 4.7485197342,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 3.0,
#   '75%': 5.0,
#   'max': 47.0,
#   'corr': 0.61},
#  {'indicator': 'var20',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 12,
#   'mean': 0.1369294606,
#   'std': 0.7086401429,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 13.0,
#   'corr': 0.2},
#  {'indicator': 'var21',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 19,
#   'mean': 0.7693637621,
#   'std': 1.8331628975,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 1.0,
#   'max': 26.0,
#   'corr': 0.33},
#  {'indicator': 'var22',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 29,
#   'mean': 0.4170124481,
#   'std': 2.685206986,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 50.0,
#   'corr': 0.12},
#  {'indicator': 'var23',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 11,
#   'mean': 0.3589211618,
#   'std': 0.895323921,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 23.0,
#   'corr': 0.31},
#  {'indicator': 'var24',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 93,
#   'mean': 3.7764009403,
#   'std': 3.3455452421,
#   'min': 0.0,
#   '25%': 1.0,
#   '50%': 3.0,
#   '75%': 5.9615,
#   'max': 26.0,
#   'corr': 0.57},
#  {'indicator': 'var25',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 1717,
#   'mean': 58.5065871369,
#   'std': 62.3439753037,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 60.07,
#   '75%': 82.8325,
#   'max': 251.18,
#   'corr': 0.47},
#  {'indicator': 'var28',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 178,
#   'mean': 57.4336099585,
#   'std': 64.1763725839,
#   'min': -4.0,
#   '25%': 12.0,
#   '50%': 35.0,
#   '75%': 84.0,
#   'max': 561.0,
#   'corr': 0.41},
#  {'indicator': 'var29',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 340,
#   'mean': 5.9927593361,
#   'std': 11.2813576288,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.605,
#   '75%': 7.5,
#   'max': 69.0,
#   'corr': 0.27},
#  {'indicator': 'var30',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 340,
#   'mean': 5.9927593361,
#   'std': 11.2813576288,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.605,
#   '75%': 7.5,
#   'max': 69.0,
#   'corr': 0.27},
#  {'indicator': 'var31',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 242,
#   'mean': 107.8177731674,
#   'std': 87.4934221305,
#   'min': 0.0,
#   '25%': 39.0,
#   '50%': 97.0,
#   '75%': 155.0,
#   'max': 682.0,
#   'corr': 0.57},
#  {'indicator': 'var31b',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 84,
#   'mean': 9.9069847856,
#   'std': 15.9355105886,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 17.0,
#   'max': 125.0,
#   'corr': 0.43},
#  {'indicator': 'var31c',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 140,
#   'mean': 56.3779391425,
#   'std': 37.0171270788,
#   'min': 0.0,
#   '25%': 25.0,
#   '50%': 55.0,
#   '75%': 81.0,
#   'max': 158.0,
#   'corr': 0.62},
#  {'indicator': 'var32a',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 108,
#   'mean': 31.1310511757,
#   'std': 31.1234880546,
#   'min': 0.0,
#   '25%': 9.0,
#   '50%': 22.0,
#   '75%': 44.0,
#   'max': 216.0,
#   'corr': 0.49},
#  {'indicator': 'var32b',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 114,
#   'mean': 35.3530428769,
#   'std': 31.9623315957,
#   'min': 0.0,
#   '25%': 11.0,
#   '50%': 29.0,
#   '75%': 51.0,
#   'max': 205.0,
#   'corr': 0.5},
#  {'indicator': 'var32c',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 127,
#   'mean': 39.1587136929,
#   'std': 35.6928272116,
#   'min': 0.0,
#   '25%': 12.0,
#   '50%': 29.0,
#   '75%': 57.0,
#   'max': 263.0,
#   'corr': 0.51},
#  {'indicator': 'var32d',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 25,
#   'mean': 2.1749654219,
#   'std': 4.6641425841,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 2.0,
#   'max': 48.0,
#   'corr': 0.16},
#  {'indicator': 'var33',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 3,
#   'mean': 1.1320885201,
#   'std': 0.9045681724,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 1.0,
#   '75%': 2.0,
#   'max': 2.0,
#   'corr': 0.78},
#  {'indicator': 'var34',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 38,
#   'mean': 4.0224757953,
#   'std': 4.7485197342,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 3.0,
#   '75%': 5.0,
#   'max': 47.0,
#   'corr': 0.61},
#  {'indicator': 'var35',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 9,
#   'mean': 0.1317427386,
#   'std': 0.5871935541,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 0.0,
#   '75%': 0.0,
#   'max': 12.0,
#   'corr': 0.14},
#  {'indicator': 'webquest01',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 11,
#   'mean': 3.7652143845,
#   'std': 3.4639808192,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 4.0,
#   '75%': 6.0,
#   'max': 10.0,
#   'corr': 0.68},
#  {'indicator': 'webquest02',
#   'type': 'Discreto',
#   'missing': 0,
#   'unique': 11,
#   'mean': 3.8025587828,
#   'std': 3.5343969256,
#   'min': 0.0,
#   '25%': 0.0,
#   '50%': 4.0,
#   '75%': 6.0,
#   'max': 10.0,
#   'corr': 0.71}]
