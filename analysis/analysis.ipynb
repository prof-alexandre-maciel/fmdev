# %%
import pandas as pd

# %%
df = pd.read_csv('data/base_desempenho_completa.csv', sep=';', low_memory=False)
# df = pd.read_csv('data/dicionario_dadosDesempenho.csv', sep=';', low_memory=False)

# %%
df.head()

# Performance E = ( ) xams * . 5 5 +( ) Forum W * . 2 0 +( ebQuest * . 2 5)
# Out:
#        Curso  Semestre  Período                 Nome da Disciplina  \
# 0  Pedagogia    2014.2        5  Educação de Jovens e Adultos (5º)
# 1   Biologia    2013.2        6                        Prática VI
# 2  Pedagogia    2014.1        4              Prática Pedagógica IV
# 3  Pedagogia    2016.1        8          Avaliação da Aprendizagem
# 4   Biologia    2013.2        3        Psicologia da Aprendizagem
#
#    ID da Disciplina  Data de Início  Data de Final  \
# 0               116      1404172800     1420070399
# 1                36      1372636800     1388361600
# 2                49      1388534400     1404172799
# 3                63      1451606400     1467331199
# 4                30      1372636800     1388361600
#
#                                   Nome do Aluno  ID do Aluno  VAR01  ...  \
# 0  Ana Paula Oliveira dos Santos_Ped Gar 2012.2          882      8  ...
# 1                     WAGNER  MACEDO CAVALCANTI          441      1  ...
# ...
